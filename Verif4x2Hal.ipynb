# %%
##############################################
# Vérification que le bibteX n'a pas d'erreurs d'accollades, de parenthèses et de virgules
# Si tout est correct avec cette vérif mais que ça ne passe pas sur x2hal: regarder dans chaque champ (ex: Prénom Nom AND dans le champ auteur)
# Si tout va mal(message d'erreur du script) : regarder ce qui saute aux yeux et relire la doc
##############################################

######################################################################################################################################
### LE NOM DE FICHIER DOIT ETRE PRÉCISÉ ICI (il doit être dans le même répertoire que le script, sinon, indiquer le chemin d'accès)###
fichier_a_verifier = "../BUGS/ILL6.bib"
######################################################################################################################################

# Fonction vers laquelle on renvoie à chaque ligne du fichier bib, sauf l'avant-dernière ligne de chaque entrée bibteX (traitement spécial)
# Les 3 fonctions suivantes sont dans l'ordre inverse d'utilisation par le script et précèdent la commande principale.

def check_ligne(field_name, field_value, errors):

    corrected_field_value = field_value  # Initialisation de la valeur corrigée
    if field_name == "":
        return  corrected_field_value,errors
    # if not (field_value.startswith('{') or field_value.startswith('(')):  # pas d'accolade ouvrante, pas de parenthèse ouvrante
    #         if not (field_value.endswith('},') or field_value.endswith('}') or field_value.endswith('),') or field_value.endswith(')')): # si pas de }, pas de } pas de ), pas de )
    #             errors.append(f"Pour le champ '{field_name}', il y a ni accollades ni parenthèses (vous devrez en ajouter si vous le souhaitez dans le fichier corrigé).")
    if field_value.startswith('{') and not (field_value.endswith('}') or field_value.endswith('},')):
        if field_value.endswith(')') or field_value.endswith('),'):
            errors.append(f"Pour le champ '{field_name}', il y a une accolade ouvrante mais une parenthèse fermante.")
            corrected_field_value = corrected_field_value.replace(')', '}')# Correction
        else:
            errors.append(f"Pour le champ '{field_name}', il manque l'accollade fermante.")
            corrected_field_value = corrected_field_value + '}'  # Correction
    if not field_value.startswith('{') and (field_value.endswith('}') or field_value.endswith('},')):
        if field_value.startswith('('):
            errors.append(f"Pour le champ '{field_name}', il y a une parenthèse ouvrante mais une accolade fermante.")
            corrected_field_value = corrected_field_value.replace('}', ')')# Correction
        else:
            errors.append(f"Pour le champ '{field_name}', il manque l'accollade ouvrante.")
            corrected_field_value = '{' + corrected_field_value # Correction
    if field_value.startswith('(') and not (field_value.endswith(')') or field_value.endswith('),')) :
        if not field_value.endswith('}') and not field_value.endswith('},'):
            errors.append(f"Pour le champ '{field_name}', il manque la parenthèse fermante.")
            corrected_field_value = corrected_field_value + ')' # Correction
    if not field_value.startswith('(') and (field_value.endswith(')') or field_value.endswith('),')):
        if not field_value.startswith('{'):
            errors.append(f"Pour le champ '{field_name}', il manque la parenthèse ouvrante.")
            corrected_field_value = '(' + corrected_field_value # Correction
    if not field_value.endswith(','):
        errors.append(f"Pour le champ '{field_name}', il manque la virgule finale.")
        corrected_field_value = corrected_field_value + ',' # Correction
    return corrected_field_value, errors  # Retourne la valeur corrigée en plus des erreurs

# Fonction vers laquelle on renvoie l'avant-dernière ligne de l'entrée bibteX
def check_avantderniereligne(field_name, field_value, errors):
    corrected_field_value = field_value  # Initialisation de la valeur corrigée
    # if not (field_value.startswith('{') or field_value.startswith('(')): 
    #         if not (field_value.endswith('},') or field_value.endswith('}') or field_value.endswith('),') or field_value.endswith(')')):
    #             errors.append(f"Pour le champ '{field_name}', il y a ni accollades ni parenthèses (vous devrez le corriger dans le fichier corrigé).")
    if field_value.startswith('{') and not (field_value.endswith('}') or field_value.endswith('},')):
        if field_value.endswith(')') or field_value.endswith('),'):
            errors.append(f"Pour le champ '{field_name}', il y a une accolade ouvrante mais une parenthèse fermante.")
            corrected_field_value = corrected_field_value.replace(')', '}')# Correction
        else:
            errors.append(f"Pour le champ '{field_name}', il manque l'accollade fermante*.")
            corrected_field_value = field_value + '}'  # Correction
    if not field_value.startswith('{') and (field_value.endswith('}') or field_value.endswith('},')):
        if field_value.startswith('('):
            errors.append(f"Pour le champ '{field_name}', il y a une parenthèse ouvrante mais une accolade fermante.")
            corrected_field_value = corrected_field_value.replace('}', ')')# Correction
        else:
            errors.append(f"Pour le champ '{field_name}', il manque l'accollade ouvrante.")
            corrected_field_value = '{' + corrected_field_value # Correction
    if field_value.startswith('(') and not (field_value.endswith(')') or field_value.endswith('),')) :
        if not field_value.endswith('}') and not field_value.endswith('},'):
            errors.append(f"Pour le champ '{field_name}', il manque la parenthèse fermante.")
            corrected_field_value = corrected_field_value + ')' # Correction
    if not field_value.startswith('(') and (field_value.endswith(')') or field_value.endswith('),')):
        if not field_value.startswith('{'):
            errors.append(f"Pour le champ '{field_name}', il manque la parenthèse ouvrante.")
            corrected_field_value = '(' + corrected_field_value # Correction
    return corrected_field_value, errors  # Retourne la valeur corrigée en plus des erreurs

# Fonction qui vérifie le fichier ligne par ligne et utilise les 2 fonctions ci-dessus
def check_bibtex_text(text):
    lines = text.split('\n')
    errors = []
    corrected_entries = []
    in_entry = False  # Variable pour suivre si on est dans une entrée BibTeX

    for line_num, line in enumerate(lines):
        line = line.strip()

        # Ignorer les lignes vides
        if not line:
            corrected_entries.append(line)
            continue

        # Vérifier si la ligne commence par un identifiant d'entrée BibTeX
        if line.startswith('@'):
            # Si on est déjà dans une entrée et qu'on en rencontre une nouvelle, il manque une accolade fermante
            if in_entry:
                errors.append(f"Erreur à la ligne {line_num + 1} : Il manque une accolade fermante '}}' pour l'entrée BibTeX précédente.")
            in_entry = True
            # Trouver l'index de l'accolade ouvrante '{'
            start_index = line.find('{')
            # Trouver l'index de la virgule après l'accolade ouvrante
            end_index = line.find(',', start_index)
            # Extraire le texte entre l'accolade ouvrante et la virgule
            identifier = line[start_index + 1: end_index]
            errors.append(identifier)
            corrected_entries.append(line)

            if not line.endswith(','):
                errors.append(f"Erreur à la ligne {line_num + 1} : La première ligne de l'entrée BibTeX ne se termine pas par une virgule. Ligne complète : {line}")
        else:
            # Si la ligne contient un '=', on est dans une entrée BibTeX
            if '=' in line:
                in_entry = True
                field_name, field_value = map(str.strip, line.split('=', 1))
                if line_num + 1 < len(lines) and lines[line_num + 1].strip() == '}' or lines[line_num + 1].strip() == '},':
                    corrected_field_value, errors = check_avantderniereligne(field_name, field_value, errors)
                else:
                    corrected_field_value, errors = check_ligne(field_name, field_value, errors)
                line = f"{field_name} = {corrected_field_value}"
                corrected_entries.append(line)
            else:
                # Si la ligne ne contient pas de '=', on vérifie si c'est la fin d'une entrée BibTeX
                if line == '}' or line == '},':
                    in_entry = False
                    corrected_entries.append(line)
                else:
                    # Si on est dans une entrée et qu'on ne trouve pas de '}', il y a une erreur
                    if in_entry:
                        errors.append(f"Erreur à la ligne {line_num + 1} : Il manque une accolade fermante '}}' pour l'entrée BibTeX en cours.")
                    corrected_entries.append(line)

    # Écrire les entrées corrigées dans un nouveau fichier
    with open('fichier_corrige.bib', 'w', encoding='utf-8') as corrected_file:
        for entry in corrected_entries:
            corrected_file.write(entry + '\n')

    return errors
######################################################
# Commande principale : lire le contenu du fichier .bib (noter que bibtexparser ne permet pas de faire ce repérage)
######################################################
with open(fichier_a_verifier, encoding='utf-8') as bibtex_file:
    bibtex_content = bibtex_file.read()


# Analyser le contenu comme un texte normal
errors = check_bibtex_text(bibtex_content)

# Afficher les erreurs
if errors:
    print("Erreurs détectées dans le texte BibTeX :")
    for error in errors:
        print(error)
else:
    print("Aucune erreur détectée dans le texte BibTeX.")

print ("Fichier bibtex_corrige.bib créé")
# Out:
# Erreurs détectées dans le texte BibTeX :
# rodzinka_neutron_2024
# Erreur à la ligne 17 : Il manque une accolade fermante '}' pour l'entrée BibTeX précédente.
# totzke_non-invasive_2024
# drago_neutron_2024
# schwaighofer_oxide_2024
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 56 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 57 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 58 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 59 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 60 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 61 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 63 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 65 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 66 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 67 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 68 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 69 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 70 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 71 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 72 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 73 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 74 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 75 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 76 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 77 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 78 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 79 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 80 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 81 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 82 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 83 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 84 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 85 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 86 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 87 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 88 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 89 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 90 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 91 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 92 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 93 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 95 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 97 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# gilbert_interactions_2024
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 116 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 117 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# callaway_nanoscale_2024
# bousquet_sign_2024
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 154 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 155 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 156 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 157 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 158 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 159 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 160 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 161 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 162 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 163 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 164 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 165 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 166 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 167 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 168 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 169 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 170 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 171 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 172 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 179 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 181 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 187 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 188 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 189 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 190 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 191 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 192 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 193 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 194 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 195 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 202 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 204 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 210 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 217 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 219 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 225 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 232 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 234 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 240 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# munoz_new_2024
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 258 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 259 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 260 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 261 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 262 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 263 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 264 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 265 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 266 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 267 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 268 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 269 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 270 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 271 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 272 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 273 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 274 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 275 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 276 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 277 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 278 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 279 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 280 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 281 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 282 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 283 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 285 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 286 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 287 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 288 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 289 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 290 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 291 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 292 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 293 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# sporer_optimized_2024
# radzina_novel_2024
# rizell_neutron_2023
# pulvermacher_neutronographic_2023
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 365 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 368 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 371 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 372 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 377 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# hu_neutron_2023
# fallarini_niosomes_2023
# zajic_ndyag_2023
# schwaighofer_oxide_2023
# gonzalez_szwacki_orthorhombic_2023
# manasi_nanostructure_2023
# gvaramia_neutron_2023
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 503 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# geers_non-collinear_2023
# Pour le champ 'abstract', il y a une accolade ouvrante mais une parenthèse fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 522 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Pour le champ 'M', il manque la virgule finale.
# Erreur à la ligne 525 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 527 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 528 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 529 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 530 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 531 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 532 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 533 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 534 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 535 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 536 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 537 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 538 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 539 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 541 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 542 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 543 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 544 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 546 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 547 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 548 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 549 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 551 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 552 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 553 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 554 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# jafari_ne_2023
# nambu_neutron_2023
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 591 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 593 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 594 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 596 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 597 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 598 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 599 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 600 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 601 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 602 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# law_neutron_2023
# urru_neutron_2023
# miele_nanoclay-doped_2023
# danner_neutron_2023
# osswald_highly_2023
# liu_numerical_2023
# kelley_nanoscale_2023
# klos_neutron_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 750 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 751 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 752 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 753 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 754 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 755 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 756 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 757 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 758 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 759 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 760 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 762 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 763 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 765 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 767 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 769 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 771 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 773 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 775 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 776 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 777 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 778 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 779 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 780 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# zapata-ramirez_optimisation_2022
# prehal_nanoscale_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 816 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 817 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 818 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 819 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 820 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 821 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 822 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 823 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 824 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 825 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 826 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# yunoki_overall_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 845 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# serrano-sanchez_magnetic_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 864 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 866 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 867 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 868 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 869 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 870 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 871 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 872 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 873 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 874 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 875 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 877 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 879 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 880 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 881 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 882 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 883 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 885 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 886 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 888 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 889 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 890 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 891 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 892 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 893 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 894 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 896 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 897 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 899 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 901 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 902 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 903 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 904 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 906 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 907 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 908 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 909 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 910 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 911 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 912 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 913 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 914 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 915 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 916 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 917 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 918 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 919 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 920 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 921 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 922 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 923 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 924 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 925 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 926 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 927 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 928 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 929 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 931 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 932 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 933 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 934 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 935 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 936 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 937 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# sebastiani_night-time_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 956 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 957 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 959 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 961 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 962 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 963 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 964 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 965 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 966 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 967 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 968 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 969 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 970 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 971 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 972 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 973 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 974 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 975 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 976 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 977 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 978 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 979 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 980 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 981 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 982 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 983 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 984 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 986 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 987 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 989 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 990 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 991 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 992 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 993 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# rosler_nematic_2022
# qureshi_non-collinear_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 1028 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1031 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1035 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1040 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1043 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1047 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1052 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1053 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1056 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1059 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1061 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1062 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1069 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1070 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1071 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1072 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1073 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1076 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1079 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1084 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1087 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1090 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1092 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1093 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1102 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1105 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1107 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1108 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1114 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1115 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# boyd_structure_2021
# ahmadi_nanoscale_2022
# ludwig_oscillatory_2022
# Pour le champ 'abstract', il manque l'accollade fermante.
# Pour le champ 'abstract', il manque la virgule finale.
# Erreur à la ligne 1164 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1166 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1167 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1168 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1169 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1170 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1171 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1172 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# Erreur à la ligne 1173 : Il manque une accolade fermante '}' pour l'entrée BibTeX en cours.
# pulvermacher_neutronographic_2022
# orozco_rodriguez_new_2022
# Fichier bibtex_corrige.bib créé

# %% [markdown]
# Repérage des sauts de ligne en plus

# %%
# Maintenant que l'on a un fichier bibteX correctement formé, on peut utiliser bibtexparser pour l'analyser
# la commande "pip install" permet d'installer la bibliothèque (=série de fonctions) dont le script a besoin
pip install bibtexparser

# %%
################################################
# Le fichier utilisé est celui créé précédemment : fichier_corrige.bib (nom modifiable ci-dessous)
# Fichier utilisé uniquement pour le repérage de la présence ou non des champs obligatoires de HAL dans le fichier bib
# Dans le bloc de script suivante la vérification est plus complète et crée un nouveau fichier qui ajoute les champs manquants aux références qui en ont besoin
# Donc, si vous souhaitez obtenir un fichier contenant les champs manquants, passez ce bloc sans l'exécuter.
################################################
import bibtexparser

### Le cas échéant, modifier le nom du fichier à analyser ci-dessous
fichier_verif_champs = "fichier_corrige.bib"
##########################################################

# Définir les champs requis pour chaque type de document (n'hésitez pas à proposer des lignes supplémentaires pour compléter)
required_fields = {
    'article': ['title', 'author', 'journal', 'year', 'pdf', 'x-filesource', 'x-audience', 'x-popularlevel', 'x-peerreviewing', 'x-language'],
    'inproceedings': ['title', 'author', 'booktitle', 'address', 'year', 'pdf', 'x-filesource', 'x-conferencestartdate', 'x-audience', 'x-language', 'x-invitedcommunication', 'x-peerreviewing', 'x-popularlevel', 'x-proceedings'],
    'conference': ['title', 'author', 'booktitle', 'address', 'year', 'pdf', 'x-filesource', 'x-conferencestartdate', 'x-audience', 'x-language', 'x-invitedcommunication', 'x-popularlevel', 'x-proceedings', 'x-peerreviewing'],
    'inbook': ['title', 'author', 'booktitle', 'year', 'pdf', 'x-filesource', 'x-audience', 'x-language', 'x-popularlevel'],
    'unpublished': ['title', 'author', 'year', 'pdf', 'x-filesource', 'x-language'],
    'misc' : ['title', 'author', 'year', 'x-audience', 'x-language', 'x-popularlevel'],
    'book' : ['title', 'author', 'year', 'x-audience', 'x-language', 'x-popularlevel'],
    'techreport' : ['title', 'author', 'year', 'x-audience', 'x-language', 'x-popularlevel'],
}

# Lire le fichier BibTeX
with open(fichier_verif_champs, encoding='utf-8') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# Vérifier les champs pour chaque entrée
for entry in bib_database.entries:
    entry_type = entry['ENTRYTYPE'].lower()
    if entry_type in required_fields:
        required = required_fields[entry_type]
        missing_fields = [field for field in required if field not in entry]
        if missing_fields:
            print(f"Entrée {entry['ID']} ({entry_type}) manque(nt) le(s) champ(s) suivants : {', '.join(missing_fields)}")
        else:
            print(f"Entrée {entry['ID']} ({entry_type}) est complète.")
    else:
        print(f"Type d'entrée non reconnu : {entry_type}")

# %% [markdown]
# Version "light"

# %%
################################################
# Le fichier utilisé est celui créé précédemment : fichier_corrige.bib (nom modifiable ci-dessous)
# Fichier utilisé uniquement pour le repérage de la présence ou non des champs obligatoires de HAL dans le fichier bib
# Dans le bloc de script suivante la vérification est plus complète et crée un nouveau fichier qui ajoute les champs manquants aux références qui en ont besoin
# Donc, si vous souhaitez obtenir un fichier contenant les champs manquants, passez ce bloc sans l'exécuter.
################################################
import bibtexparser

### Le cas échéant, modifier le nom du fichier à analyser ci-dessous
fichier_verif_champs = "fichier_corrige.bib"
##########################################################

# Définir les champs requis pour chaque type de document (n'hésitez pas à proposer des lignes supplémentaires pour compléter)
required_fields = {
    'article': ['title', 'author', 'journal', 'year', 'pdf', 'x-language', 'x-domain'],
    'inproceedings': ['title', 'author', 'booktitle', 'address', 'year', 'x-domain','x-conferencestartdate', 'x-language' ],
    'conference': ['title', 'author', 'booktitle', 'address', 'year', 'x-domain','x-conferencestartdate', 'x-language'],
    'poster': ['title', 'author', 'booktitle', 'address', 'year', 'x-domain','x-conferencestartdate', 'x-language'],
    'proceedings': ['title', 'author', 'year', 'x-domain', 'x-language'],
    'incollection': ['title', 'author', 'booktitle', 'year', 'x-language', 'x-domain'],
    'inbook': ['title', 'author', 'booktitle', 'year', 'x-language', 'x-domain'],
    'book': ['title', 'author', 'year', 'x-language', 'x-domain'],
    'phdthesis': ['x-title_fr' ,  x-'title_en' ,  'author' , 'x-dateDefended', 'x-abstract_fr', 'x-abstract_en',  'school',  'year' ,  'x-director' ,  'x-language',  'type',  'x-domain' ],
    'unpublished': ['title', 'author', 'year', 'comment', 'x-domain', 'x-language'],
    'misc' : ['title', 'author', 'year', 'note', 'x-language', 'x-domain'],
    'book' : ['title', 'author', 'year', 'x-audience', 'x-language', 'x-popularlevel'],
    'techreport' : ['title', 'author', 'year', 'x-reporttype', 'x-language', 'x-domain'],
    'patent ' : ['title', 'author', 'year', 'x-country', 'x-language', 'x-domain'],    
}

# Lire le fichier BibTeX
with open(fichier_verif_champs, encoding='utf-8') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# Vérifier les champs pour chaque entrée
for entry in bib_database.entries:
    entry_type = entry['ENTRYTYPE'].lower()
    if entry_type in required_fields:
        required = required_fields[entry_type]
        missing_fields = [field for field in required if field not in entry]
        if missing_fields:
            print(f"Entrée {entry['ID']} ({entry_type}) manque(nt) le(s) champ(s) suivants : {', '.join(missing_fields)}")
        else:
            print(f"Entrée {entry['ID']} ({entry_type}) est complète.")
    else:
        print(f"Type d'entrée non reconnu : {entry_type}")

# %%
#######################################
# fichier utilisé est le fichier corrigé précédemment : bibtex_corrige.bib, le nom peut être modifié ci-dessous
# Ce script repère les champs manquants et les ajoute, créant ainsi un nouveau fichier "nouveau_fichier_complet.bib"
# Détection des champs obligatoires manquants
# ajout de ces champs (il faudra ensuite choisir les valeurs adaptées)
#########################################


#### Le cas échéant, modifier le nom du fichier à analyser ci-dessous
fichier_verif_champs = "fichier_corrige.bib"
##########################################################

import bibtexparser

# Définir les champs requis pour chaque type de document
required_fields = {
    'article': {
        'title': '',
        'author': '',
        'journal': '',
        'year': '',
        'pdf': '',
        'x-filesource': 'valeurs possibles: author,greenPublisher,publisherAgreement,publisherPaid',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-peerreviewing': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-language': 'valeurs possibles:en,fr ou code iso ISO 639-1'
    },
    'inproceedings': {
        'title': '',
        'author': '',
        'booktitle': '',
        'address': '',
        'year': '',
        'pdf': '',
        'x-conferencestartdate': 'AAAA',
        'x-invitedcommunication': '{Valeurs possibles : Oui, Yes, Non, No}',
        'x-proceedings': 'Valeurs possibles : Oui, Yes, Non, No',  
        'x-filesource': 'valeurs possibles: author,greenPublisher,publisherAgreement,publisherPaid',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-peerreviewing': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-language': 'valeurs possibles:en,fr ou code iso ISO 639-1'
    },
    'conference': {
        'title': '',
        'author': '',
        'booktitle': '',
        'address': '',
        'year': '',
        'x-conferencestartdate': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-invitedcommunication': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-proceedings': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-peerreviewing': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'presconf': {
        'title': '',
        'author': '',
        'booktitle': '',
        'year': '',
        'address': '',
        'x-conferencestartdate': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-invitedcommunication': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-peerreviewing': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-proceedings': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-inria_presconftype': 'Valeurs possibles : Non spécifiée, Not specified, Tutoriel, Tutorial, Présentation, Presentation, Papier court, Short paper, Préface, Preface, Synthèse de conférence, Conference digest, Guest Editorial, Guest Editorial',
    },
    'poster': {
        'title': '',
        'author': '',
        'booktitle': '',
        'year': '',
        'address': '',
        'x-conferencestartdate': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-invitedcommunication': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-peerreviewing': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
        'x-proceedings': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'incollection': {
        'title': '',
        'author': '',
        'booktitle': 'Titre de l@ouvrage',
        'year': '2015',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'inbook': {
        'title': '',
        'author': '',
        'booktitle': 'Titre de l@ouvrage',
        'year': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'book': {
        'title': '',
        'author': '',
        'year': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'proceedings': {
        'title': '',
        'author': '',
        'year': 'AAAA',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'phdthesis': {
        'title': '',
        'author': '',
        'school': 'Université de Sophia Antipolis',
        'year': 'AAAA',
        'pdf': 'https://hiepacs/files/2015/MasterHiep/pdf',
        'x-director': 'director',
        'x-language': 'en',
        'x-title_fr': 'Obligatoire si le titre est en anglais',
        'x-title_en': 'Obligatoire si le titre est en français',
        'x-abstract_fr': 'Résumé en français',
        'x-abstract_en': 'Abstract',
        'x-keywords_fr': 'mot1 ; mot2',
        'x-keywords_en': 'word1 ; word2',
        'x-filesource': 'Valeurs possibles : author, greenPublisher, publisherAgreement, publisherPaid',
    },
    'misc': {
        'title': '',
        'author': '',
        'year': 'AAAA',
        'note': 'descrition',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-popularlevel': 'Valeurs possibles : Oui, Yes, Non, No',
    },
    'techreport': {
        'title': '',
        'author': '',
        'institution': 'Université de Rennes 1',
        'year': 'AAAA',
        'x-language': 'en',
        'x-reporttype': 'Valeurs possibles : Rapport de recherche, Research Report, Rapport Technique, Technical Report, Contrat, Contrat, Stage, Stage, Interne, Interne, Travaux universitaires, Univ works, Autre, Other',
    },
    'patent': {
        'title': '',
        'author': '',
        'year': 'AAAA-MM-DD',
        'number': '01',
        'x-country': 'FR',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
    },
    'unpublished': {
        'title': '',
        'author': '',
        'year': 'AAAA',
        'x-language': 'en',
    },
    'mastersthesis': {
        'title': '',
        'author': '',
        'school': 'Indiquez école doctorale',
        'year': 'AAAA',
        'pdf': '',
        'x-inria_degreetype': 'Valeurs possibles : Mémoire de Master 2, Master thesis 2, Mémoire de Master 1, Master thesis 1, Mémoire d@Ingénieur, Engineering school master thesis, Rapport de stage de Master 2, Master 2 probation report, Mémoire de D.E.A., D.E.A. Master thesis, Mémoire de Master 2 Pro, Professional master thesis 2, Mémoire de Master 1 Pro, Professional master thesis 1, Mémoire de Maîtrise, Master thesis, Mémoire de D.U., University degree probation report, Rapport de stage de Master 1, Master 1 probation report, Mémoire du Conservatoire national des arts et métiers (Cnam), Cnam probation report, Mémoire de D.E.S.S., D.E.S.S Master thesis, Rapport final de Travail de Fin d@Etudes, Final report of studies end',
        'x-director': 'director',
        'x-audience': 'Valeurs possibles : Internationale, International, Nationale, National, Non spécifiée, Not set',
        'x-language': 'en',
        'x-inria_directoremail': 'alain.monteil(at)inria.fr',
        'x-filesource': 'Valeurs possibles : author, greenPublisher, publisherAgreement, publisherPaid',
    },
    'note': {
        'title': 'Ceci est le titre de la note',
        'author': '',
        'year': 'AAAA',
        'x-language': 'en',
    },
}

# Lire le fichier BibTeX
with open(fichier_verif_champs, encoding='utf-8') as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# Créer une nouvelle base de données BibTeX
new_bib_database = bibtexparser.bibdatabase.BibDatabase()
new_bib_database.entries = []  # Initialise la liste des entrées

# Ajouter chaque entrée avec les champs manquants
for entry in bib_database.entries:
    #print("je regarde une entrée")
    entry_type = entry['ENTRYTYPE'].lower()
    new_entry = entry.copy()  # Faire une copie de l'entrée existante
    if entry_type in required_fields:
        required = required_fields[entry_type]
        for field in required:
            if field not in new_entry:
                new_entry[field] = required[field]  # Utilisation des valeurs par défaut définies
    new_bib_database.entries.append(new_entry)  # Ajouter l'entrée (modifiée ou non) à la nouvelle base de données

# Écrire la nouvelle base de données BibTeX dans un fichier
with open('nouveau_fichier_complet.bib', 'w', encoding='utf-8') as new_bibtex_file:
    bibtexparser.dump(new_bib_database, new_bibtex_file)

print("fichier complet enregistré")
